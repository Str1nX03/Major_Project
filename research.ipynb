# %%
from src.utils import get_llm

llm = get_llm()
name = "Dravin"
prompt = f"""

Hey, my name is {name}. Who are you?

"""

response = llm.invoke(prompt)

# %%
print(response.content)
# Out:
# Nice to meet you, Dravin. I'm an artificial intelligence model, often referred to as a conversational AI or chatbot. I'm here to assist and provide information on a wide range of topics. I don't have a personal name, but I'm happy to chat with you and help with any questions or topics you'd like to discuss. How's your day going so far?

# %%
from src.agents.assistant_agent import ManagerAgent

manager_agent = ManagerAgent()
response = manager_agent.run(standard = 1, subject = "Maths", topic = "Multiplication")

# %%
from langchain_tavily import TavilySearch
from src.utils import get_llm
from langchain_core.messages import SystemMessage
from dotenv import load_dotenv
import os
load_dotenv()

tool = [TavilySearch(max_results=3, topic="general", api_key = os.getenv("TAVILY_API_KEY"))]

llm = get_llm()

topic = "Multiplication"
subject = "Maths"
standard = 1



prompt_1 = f"""

        Give me a study materials and general intro on the topic: {topic} from the subject: {subject} for the student of standard: {standard}.

"""
response_1 = tool[0].invoke(prompt_1)

prompt_2 = f"""

        You are a teacher. Your task is to provide the instructions to the user for a particular topic.
        You will give a general idea about the topic like how difficult it is and what are the pre-requisites to study the topic.
        You will also give a brief introduction on this topic to the user.
        
        These are the general instructions provided by the user:-

        1. The topic that is needed to be taught to the user is :- {topic}
        2. The subject that is needed to be taught to the user is :- {subject}
        3. The standard that the user currently is in with respect to Indian standard (School) :- {standard}

        These are the study materials and general intro provided by the user:-

        {response_1}

        So provide the links of the study materials and intro to the study materials as well along with the general intro to the topic.

        """

response_2 = llm.invoke([SystemMessage(content = prompt_2)])

# %%
print(response_2.content)
# Out:
# **Introduction to Multiplication**
#
# Hello student! I'm excited to introduce you to the concept of multiplication in Maths. Multiplication is a fundamental operation in Maths that helps us find the product of two or more numbers. It's an essential skill to master, and with practice, you'll become proficient in no time.
#
# **Difficulty Level:** Easy to Moderate
#
# **Pre-requisites:** You should have a basic understanding of numbers, addition, and subtraction.
#
# **What is Multiplication?**
#
# Multiplication is often referred to as repeated addition. For example, 3 x 4 can be thought of as 3 groups of 4, which equals 12. This concept is easy to understand and visualize, making it a great starting point for young learners like you.
#
# **Study Materials:**
#
# Here are some excellent resources to help you learn multiplication:
#
# ...

# %%
response_1
# Out:
# {'query': 'Give me a study materials and general intro on the topic: Multiplication from the subject: Maths for the student of standard: 1.',
#  'follow_up_questions': None,
#  'answer': None,
#  'images': [],
#  'results': [{'url': 'https://www.teacherspayteachers.com/Product/Introduction-to-Multiplication-for-Grade-1-4976486',
#    'title': 'Introduction to Multiplication for Grade 1 - TPT',
#    'content': 'This workbook is a complete self-learning companion for your students to learn Introduction to Multiplication. Designed by teachers with over 20 years of',
#    'score': 0.9999076,
#    'raw_content': None},
#   {'url': 'https://www.youtube.com/watch?v=2Ee4hsA1sH0',
#    'title': 'Class 1 Maths Multiplication (Complete Chapter) - YouTube',
#    'content': 'Multiplication is an important chapter for class 1 maths or grade 1 maths. Multiplication is also called as repeated addition. Learn',
#    'score': 0.9996458,
#    'raw_content': None},
# ...

# %%
from src.utils import get_llm
from langchain_core.messages import SystemMessage
llm = get_llm()

standard = 1
subject = "Mathematics"
topic_intro = """

    **Introduction to Multiplication**

Hello student! I'm excited to introduce you to the concept of multiplication in Maths. Multiplication is a fundamental operation in Maths that helps us find the product of two or more numbers. It's an essential skill to master, and with practice, you'll become proficient in no time.

**Difficulty Level:** Easy to Moderate

**Pre-requisites:** You should have a basic understanding of numbers, addition, and subtraction.

**What is Multiplication?**

Multiplication is often referred to as repeated addition. For example, 3 x 4 can be thought of as 3 groups of 4, which equals 12. This concept is easy to understand and visualize, making it a great starting point for young learners like you.

**Study Materials:**

Here are some excellent resources to help you learn multiplication:

1. **Introduction to Multiplication for Grade 1** by Teachers Pay Teachers: [https://www.teacherspayteachers.com/Product/Introduction-to-Multiplication-for-Grade-1-4976486](https://www.teacherspayteachers.com/Product/Introduction-to-Multiplication-for-Grade-1-4976486)
2. **Class 1 Maths Multiplication (Complete Chapter)** by YouTube: [https://www.youtube.com/watch?v=2Ee4hsA1sH0](https://www.youtube.com/watch?v=2Ee4hsA1sH0)
3. **Introduction of Multiplication Worksheets for Grade 1** by YouTube: [https://www.youtube.com/watch?v=nJLngAHxwg0](https://www.youtube.com/watch?v=nJLngAHxwg0)

These resources will provide you with a comprehensive understanding of multiplication, along with practice worksheets and video tutorials to help you reinforce your learning.

**Tips and Practice:**

To master multiplication, practice regularly and try to relate it to real-life situations. You can start by multiplying small numbers and gradually move on to larger numbers. Don't be afraid to ask your teacher or parents for help if you need it.

I hope this introduction to multiplication has sparked your interest in learning this essential Maths concept. Happy learning!

"""
study_links = """

{'query': 'Give me a study materials and general intro on the topic: Multiplication from the subject: Maths for the student of standard: 1.',
 'follow_up_questions': None,
 'answer': None,
 'images': [],
 'results': [{'url': 'https://www.teacherspayteachers.com/Product/Introduction-to-Multiplication-for-Grade-1-4976486',
   'title': 'Introduction to Multiplication for Grade 1 - TPT',
   'content': 'This workbook is a complete self-learning companion for your students to learn Introduction to Multiplication. Designed by teachers with over 20 years of',
   'score': 0.9999076,
   'raw_content': None},
  {'url': 'https://www.youtube.com/watch?v=2Ee4hsA1sH0',
   'title': 'Class 1 Maths Multiplication (Complete Chapter) - YouTube',
   'content': 'Multiplication is an important chapter for class 1 maths or grade 1 maths. Multiplication is also called as repeated addition. Learn',
   'score': 0.9996458,
   'raw_content': None},
  {'url': 'https://www.youtube.com/watch?v=nJLngAHxwg0',
   'title': 'Introduction of Multiplication Worksheets for Grade 1 - YouTube',
   'content': 'Hello Everyone ! Welcome to our channel Learn with Advit ! New Maths worksheets for everyone. These worksheets are for Grade 1 and Ukg kids',
   'score': 0.99929583,
   'raw_content': None}],
 'response_time': 0.0,
 'request_id': 'a27e8543-8035-4c5b-82d5-58b12c0f0e1f'}

"""
topic = "Multiplication"

prompt = f"""

            You are an agent manager and your task is to write a detailed prompt for an agent whose task is to plan lessons based on:-

            1. The topic that is needed to be taught to the user is :- {topic}
            2. The subject that is needed to be taught to the user is :- {subject}
            3. The standard that the user currently is in with respect to Indian standard (School) :- {standard}
            4. The study materials and general intro provided for the user:- {study_links}
            5. The general intro provided for the user: {topic_intro}

            You will tell the planning agent to plan for the lessons in such a way that the user will be able to understand the topic from scratch.
            The planning should start with the roots and fundamental of the topic.
            It should also include the prerequisite for the topic which is needed to be taught to the user to make the user understand the topics better.
            It should plan the lessons in step by step manner like lectures for the lessons.
            Lessons are to be taught in such a way that after completing each lesson, next lesson can be started based on the planned lessons like each level of a game.
            The planning should also include the study materials and general intro to the topic.
            You must only give the prompt for the planning agent and you do not have to plan the lessons.

            """

response = llm.invoke([SystemMessage(content=prompt)])

# %%
print(response.content)
# Out:
# **Lesson Planning Prompt for Agent**
#
# **Topic:** Multiplication
# **Subject:** Mathematics
# **Standard:** 1 (Indian Standard, School)
# **Study Materials and General Intro:** Provided in the given study materials and general intro
#
# **Planning Objective:**
#
# Plan a series of lessons that will enable the user to understand the concept of multiplication from scratch. The lessons should start with the roots and fundamentals of the topic, include prerequisite knowledge, and progress in a step-by-step manner. Each lesson should build upon the previous one, allowing the user to gradually develop a comprehensive understanding of multiplication.
#
# **Lesson Planning Requirements:**
#
# 1. **Lesson 1: Introduction to Multiplication**
# 	* Start with the general intro provided, introducing the concept of multiplication and its importance in mathematics.
# 	* Explain the concept of repeated addition and how it relates to multiplication.
# ...

# %%
from src.agents.assistant_agent import ManagerAgent

manager_agent = ManagerAgent()

response = manager_agent.run(topic="Calculus", subject="Mathematics", standard=11)

# %%
response["study_links"]["results"]
# Out:
# [{'url': 'https://www.youtube.com/playlist?list=PLMNGkRPR_6NoUtC1uQgsSxtMNMhEyV5Au',
#   'title': 'Introduction to Calculus - Year 11 Mathematics Advanced',
#   'content': 'Introduction to Calculus - Year 11 Mathematics Advanced · Gradient of a curve - Year 11 Mathematics Advanced · Differentiability - Year 11 Mathematics Advanced.',
#   'score': 0.99719906,
#   'raw_content': None},
#  {'url': 'https://www.youtube.com/watch?v=JsIbv02qCII',
#   'title': 'Calculus | HSC Year 11 Maths Advanced',
#   'content': 'An expert summary on Calculus for HSC Year 11 Maths Advanced. Covers everything you need to know to ace your exams!',
#   'score': 0.9937588,
#   'raw_content': None},
#  {'url': 'https://www.youtube.com/watch?v=GiCojsAWRj0',
#   'title': 'Calculus 1 Review - Basic Introduction',
# ...

# %%
print(response["instructions"])
# Out:
# **1. Topic Intro: Introduction to Calculus**
#
# Calculus is a branch of mathematics that deals with the study of continuous change, particularly in the context of functions and limits. It is a fundamental subject that has numerous applications in various fields, including physics, engineering, economics, and computer science. Calculus is divided into two main branches: Differential Calculus and Integral Calculus.
#
# **Difficulty Level**
#
# The difficulty level of calculus is moderate to advanced, depending on the student's background and prior knowledge. It requires a strong understanding of algebra, geometry, and trigonometry, as well as analytical and problem-solving skills.
#
# **Pre-requisites**
#
# To study calculus, you should have a good understanding of the following topics:
#
# * Algebra: equations, functions, graphs, and inequalities
# * Geometry: points, lines, planes, and solids
# * Trigonometry: triangles, angles, and wave patterns
# ...

# %%
print(response["topic_intro"])
# Out:
# **Introduction to Calculus**
#
# Calculus is a branch of mathematics that deals with the study of continuous change, particularly in the context of functions and limits. It is a fundamental subject that has numerous applications in various fields, including physics, engineering, economics, and computer science. Calculus is divided into two main branches: Differential Calculus and Integral Calculus.
#
# **Difficulty Level**
#
# The difficulty level of calculus is moderate to advanced, depending on the student's background and prior knowledge. It requires a strong understanding of algebra, geometry, and trigonometry, as well as analytical and problem-solving skills.
#
# **Pre-requisites**
#
# To study calculus, you should have a good understanding of the following topics:
#
# * Algebra: equations, functions, graphs, and inequalities
# * Geometry: points, lines, planes, and solids
# * Trigonometry: triangles, angles, and wave patterns
# ...

# %%
from langchain_tavily import TavilySearch
import os

tool = [TavilySearch(max_results=3, topic="general", api_key = os.getenv("TAVILY_API_KEY"))]
topic = "Calculus"
subject = "Mathematics"
standard = 11
prompt = f"Give me only web page based study materials from the topic: {topic} from the subject: {subject} for the student of standard: {standard}."

response = tool[0].invoke(prompt)

# %%
from src.utils import get_llm

llm = get_llm()

instructions = """

**Introduction to Calculus**

Calculus is a branch of mathematics that deals with the study of continuous change, particularly in the context of functions and limits. It is a fundamental subject that has numerous applications in various fields, including physics, engineering, economics, and computer science. Calculus is divided into two main branches: Differential Calculus and Integral Calculus.

**Difficulty Level**

The difficulty level of calculus is moderate to advanced, depending on the student's background and prior knowledge. It requires a strong understanding of algebra, geometry, and trigonometry, as well as analytical and problem-solving skills.

**Pre-requisites**

To study calculus, you should have a good understanding of the following topics:

* Algebra: equations, functions, graphs, and inequalities
* Geometry: points, lines, planes, and solids
* Trigonometry: triangles, angles, and wave patterns
* Functions: domain, range, and composition of functions

**Study Materials**

Here are some study materials and YouTube video links to help you learn calculus:

1. **Introduction to Calculus - Year 11 Mathematics Advanced** by YouTube:
	* Playlist: https://www.youtube.com/playlist?list=PLMNGkRPR_6NoUtC1uQgsSxtMNMhEyV5Au
	* Video titles: Introduction to Calculus, Gradient of a curve, Differentiability
2. **Calculus | HSC Year 11 Maths Advanced** by YouTube:
	* Video: https://www.youtube.com/watch?v=JsIbv02qCII
	* Description: An expert summary on Calculus for HSC Year 11 Maths Advanced. Covers everything you need to know to ace your exams!
3. **Grade 11 - Basic Calculus (STEM)** by YouTube:
	* Playlist: https://www.youtube.com/playlist?list=PLFG5lKeDCYPkl7euqps7r3lKL65pfnJUw
	* Video titles: Finding the limit of a function using table of values, Evaluating limits from a graph, PRACTICE PROBLEMS
4. **Calc 1, Exam 1 walkthrough (Spring 2025)** by YouTube:
	* Video: https://www.youtube.com/watch?v=FkkY8c3ISOY
	* Description: A walk-through of the solutions for Exam 1 of Calculus 1 administered in Spring 2025
5. **Basic Calculus | STEM Lessons for Grade 11 and Grade 12** by YouTube:
	* Video: https://www.youtube.com/watch?v=U48n5vYbbV8
	* Description: A walk-through on what the grade 11 or 12 student should know about basic calculus

**Tips for Learning Calculus**

1. **Start with the basics**: Make sure you have a strong understanding of algebra, geometry, and trigonometry before diving into calculus.
2. **Practice, practice, practice**: Calculus requires a lot of practice to understand and apply the concepts. Start with simple problems and gradually move on to more complex ones.
3. **Watch video lectures**: Video lectures can be a great way to learn calculus, especially if you are a visual learner. Watch video lectures from reputable sources, such as the ones listed above.
4. **Join a study group**: Joining a study group can be a great way to learn calculus, as you can discuss problems and concepts with your peers.
5. **Take your time**: Calculus is a challenging subject, so don't rush through it. Take your time to understand each concept, and don't be afraid to ask for help if you need it.

**General Intro to Calculus**

Calculus is a fascinating subject that has numerous applications in various fields. It is a fundamental subject that helps us understand how things change and move. Calculus is divided into two main branches: Differential Calculus and Integral Calculus.

Differential Calculus deals with the study of rates of change and slopes of curves. It helps us understand how functions change as their input changes.

Integral Calculus deals with the study of accumulation of quantities. It helps us understand how to find the area under curves, volumes of solids, and other quantities.

Calculus has numerous applications in various fields, including physics, engineering, economics, and computer science. It is a fundamental subject that helps us understand how things change and move, and it has numerous practical applications in real-life situations.

I hope this helps you get started with learning calculus!

"""
standard = 1
subject = "Mathematics"
topic = "Integral Calculus"

prompt = f"""

            You must read the instructions: {instructions} and plan the lessons step by step for the topic: {topic}, subject: {subject}, for the students of standard: {standard} and in comprehensive way so that even user will get time to be comfortable with the topics.
            Make the length of the lessons for about 35-50 lessons depending on the topic and its difficulty level.
            You must only generate the lessons and mark numbers to the lessons chronologically and in a step by step manner.
            Dont write literally anything else, just write the lesson number, lesson title, all the topics we will learn in that specific lesson and thats it.
            Just list down lessons in only this manner, no need to write anything else.
            Give 2 lines of gap after giving each lesson intro and in the same manner do that with every lesson from number 1 to end.

"""

response = llm.invoke(prompt)

# %%
lessons = {}
lesson_list = response.content.split("\n\n")
for lesson in lesson_list:
    print(lesson)
    print("-"*100)
# Out:
# 1. **Introduction to Integral Calculus**
#    - Definition of Integral Calculus
#    - Importance of Integral Calculus
#    - Basic Concepts of Integral Calculus
# ----------------------------------------------------------------------------------------------------
# 2. **Basic Concepts of Definite Integrals**
#    - Definition of Definite Integrals
#    - Notation and Terminology
#    - Basic Properties of Definite Integrals
# ----------------------------------------------------------------------------------------------------
# 3. **Geometric Interpretation of Definite Integrals**
#    - Area under Curves
#    - Volume of Solids
#    - Geometric Applications of Definite Integrals
# ----------------------------------------------------------------------------------------------------
# 4. **Techniques of Integration**
#    - Basic Integration Rules
#    - Substitution Method
#    - Integration by Parts
# ...

# %%
lesson_list
# Out:
# ['1. **Introduction to Integral Calculus**\n   - Definition of Integral Calculus\n   - Importance of Integral Calculus\n   - Basic Concepts of Integral Calculus',
#  '2. **Basic Concepts of Definite Integrals**\n   - Definition of Definite Integrals\n   - Notation and Terminology\n   - Basic Properties of Definite Integrals',
#  '3. **Geometric Interpretation of Definite Integrals**\n   - Area under Curves\n   - Volume of Solids\n   - Geometric Applications of Definite Integrals',
#  '4. **Techniques of Integration**\n   - Basic Integration Rules\n   - Substitution Method\n   - Integration by Parts',
#  '5. **Integration by Partial Fractions**\n   - Introduction to Partial Fractions\n   - Decomposition of Rational Functions\n   - Integration of Rational Functions',
#  '6. **Integration by Trigonometric Substitution**\n   - Introduction to Trigonometric Substitution\n   - Substitution of Trigonometric Functions\n   - Integration of Trigonometric Functions',
# ...

# %%
lessons
# Out:
# {}

# %%
response.content
# Out:
# "1. **Introduction to Integral Calculus**\n   - Definition of Integral Calculus\n   - Importance of Integral Calculus\n   - Basic Concepts of Integral Calculus\n\n2. **Basic Concepts of Definite Integrals**\n   - Definition of Definite Integrals\n   - Notation and Terminology\n   - Basic Properties of Definite Integrals\n\n3. **Geometric Interpretation of Definite Integrals**\n   - Area under Curves\n   - Volume of Solids\n   - Geometric Applications of Definite Integrals\n\n4. **Techniques of Integration**\n   - Basic Integration Rules\n   - Substitution Method\n   - Integration by Parts\n\n5. **Integration by Partial Fractions**\n   - Introduction to Partial Fractions\n   - Decomposition of Rational Functions\n   - Integration of Rational Functions\n\n6. **Integration by Trigonometric Substitution**\n   - Introduction to Trigonometric Substitution\n   - Substitution of Trigonometric Functions\n   - Integration of Trigonometric Functions\n\n7. **Improper Integrals**\n   - Definition
# ...

# %%
for lesson in lesson_list:
    
    prompt = f"You must generate comprehensive lesson contents for the lesson: {lesson}"
    response = llm.invoke(prompt)
    lessons[lesson] = response.content

# %%
lessons
# Out:
# {'1. **Introduction to Integral Calculus**\n   - Definition of Integral Calculus\n   - Importance of Integral Calculus\n   - Basic Concepts of Integral Calculus': '**Lesson Title:** Introduction to Integral Calculus\n\n**Lesson Objectives:**\n\n1. Define Integral Calculus and its importance.\n2. Explain the basic concepts of Integral Calculus.\n3. Understand the significance of Integral Calculus in various fields.\n\n**Lesson Contents:**\n\n**Section 1: Introduction to Integral Calculus**\n\n* **Definition of Integral Calculus:** Integral Calculus is a branch of mathematics that deals with the study of accumulation of quantities. It is used to find the area under curves, volumes of solids, and other quantities. The word "integral" comes from the Latin word "integer," which means "whole" or "complete."\n* **Importance of Integral Calculus:** Integral Calculus has numerous applications in various fields, including physics, engineering, economics, and computer science. It is used to sol
# ...

# %%
for lesson_name, lesson_content in lessons.items():

    print(f"**Lesson Title:** {lesson_name}\n\n")
    print(f"**Lesson Contents:**\n\n{lesson_content}\n\n")
    print("-"*100)
    print("\n\n")
# Out:
# **Lesson Title:** 1. **Introduction to Integral Calculus**
#    - Definition of Integral Calculus
#    - Importance of Integral Calculus
#    - Basic Concepts of Integral Calculus
#
#
# **Lesson Contents:**
#
# **Lesson Title:** Introduction to Integral Calculus
#
# **Lesson Objectives:**
#
# 1. Define Integral Calculus and its importance.
# 2. Explain the basic concepts of Integral Calculus.
# 3. Understand the significance of Integral Calculus in various fields.
#
# **Lesson Contents:**
#
# **Section 1: Introduction to Integral Calculus**
#
# * **Definition of Integral Calculus:** Integral Calculus is a branch of mathematics that deals with the study of accumulation of quantities. It is used to find the area under curves, volumes of solids, and other quantities. The word "integral" comes from the Latin word "integer," which means "whole" or "complete."
# ...

# %%
from src.agents.assistant_agent import AssistantAgent
from src.agents.tutoring_agent import TutoringAgent

subject = "Mathematics"
topic = "Calculus"
standard = 11

manager_agent = AssistantAgent()
response = manager_agent.run(topic="Calculus", subject="Mathematics", standard=11)

planning_agent = TutoringAgent()
response = planning_agent.run(instructions = response, subject = subject, topic = topic, standard = standard)

# %%
for intro, lesson in response.items():

    print(f"**Lesson:** {intro}\n\n")
    print(f"**Lesson Contents:**\n\n{lesson}\n\n")
    print("-"*100)
    print("\n\n")
# Out:
# **Lesson:** 1. Introduction to Calculus
#     Topics: Introduction to Calculus, Branches of Calculus, Importance of Calculus
#
#
# **Lesson Contents:**
#
# **Lesson Title:** Introduction to Calculus
#
# **Grade Level:** 11th-12th Grade
#
# **Objectives:**
#
# 1. Understand the concept of calculus and its significance in mathematics and real-world applications.
# 2. Identify the two main branches of calculus: Differential Calculus and Integral Calculus.
# 3. Recognize the importance of calculus in various fields, including physics, engineering, economics, and computer science.
#
# **Lesson Contents:**
#
# **I. Introduction to Calculus (10 minutes)**
#
# 1. **Definition of Calculus:** Introduce the concept of calculus as a branch of mathematics that deals with the study of continuous change, particularly in the context of functions and limits.
# ...
